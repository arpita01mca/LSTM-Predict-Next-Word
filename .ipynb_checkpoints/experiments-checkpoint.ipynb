# %% [markdown]
# ## Project Description: Next word prediction using LSTM

# %% [markdown]
# This project aims to develop deep learning model for predicting next word in a given sequence of words.
# The model is built using Lon Short Term Memory(LSTM) nextworks, which are well suited for sequence prediction tasks.
# The project includes the follwing steps:

# %%
1. Data Collection:

# %%
2. Data Preprocessing

# %%
3. Building Model

# %%
4. Model Training

# %%
5. Model Evaluation

# %%
6. Deployment

# %%
## Data Collection
import nltk
nltk.download('gutenberg')
from nltk.corpus import gutenberg
import pandas as pd

# %%
## load the dataset
data=gutenberg.raw('shakespeare-hamlet.txt')
## save to a file
with open('hamlet.txt','w') as file:
    file.write(data)
